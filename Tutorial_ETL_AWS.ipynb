# %% [markdown]
# <a href="https://colab.research.google.com/github/Alan-Hans/Portafolio-DataScientist/blob/main/Tutorial_ETL_AWS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tutorial ETL with AWS

# %% [markdown]
# In this project we going to perform an ETL, with the different concept that this involved, in particular, ingest data, extract data and transform data. This going to be do using Amazon web service cloud provider. <br>
# We going to advanced according: <br>
# 1.- Basic concepts.<br>
# 2.- Installation. <br>
# 2.- Ingest data.<br>
# 3.- Extractd data.<br>
# 4.- Transform data.<br>
# 5.- Deliver data<br>

# %% [markdown]
# # 1.- Basic concepst

# %% [markdown]
# There are different cloud providers and among the largest and best known we have Amazon web services, Google cloud and Microsoft Azure. In this project we going to centrate our efforts in AWS. In general, these products are used to store, transform and distribute information to the different stakeholders.They are designed to be efficient and operate with large data sizes. Besides having pre-designed tools in order to avoid having to design new tools from zero. They also provide versatility of programming languages to develop in different environments as deemed convenient. For this tutorial we going to developed in our prefered language (Python 🥰 ). <br> <br>
# There are similar services for all clouds. Below is an image with similar applications in AWS and GC.

# %% [markdown]
# ![Infografia-big-data-AWS-v3-curso-e050d8de-fa97-4248-bc00-fd17c8fd67c3.webp](data:image/webp;base64,...)
